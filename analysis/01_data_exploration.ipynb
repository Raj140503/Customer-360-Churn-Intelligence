# %%
import pandas as pd

file_path = "../data/raw/Online Retail.xlsx"

df = pd.read_excel(file_path)

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[us]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), object(3), str(1)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
df["InvoiceNo"].astype(str).str.startswith("C").sum()
# Out:
# np.int64(9288)

# %%
cancelled = df[df["InvoiceNo"].astype(str).str.startswith("C")]

cancelled.head(10)
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 141   C536379         D                           Discount        -1
# 154   C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
# 939   C536506     22960           JAM MAKING SET WITH JARS        -6
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# ...

# %%
cancelled[["InvoiceNo", "StockCode", "Description", "Quantity", "UnitPrice", "CustomerID"]].head(10)
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 141   C536379         D                           Discount        -1
# 154   C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
# 939   C536506     22960           JAM MAKING SET WITH JARS        -6
#
#      UnitPrice  CustomerID
# 141      27.50     14527.0
# 154       4.65     15311.0
# 235       1.65     17548.0
# 236       0.29     17548.0
# 237       0.29     17548.0
# 238       0.29     17548.0
# ...

# %%
(df["Quantity"] < 0).sum()
# Out:
# np.int64(10624)

# %%
(df["UnitPrice"] <= 0).sum()
# Out:
# np.int64(2517)

# %%
zero_price = df[df["UnitPrice"] <= 0]

zero_price[[
    "InvoiceNo",
    "StockCode",
    "Description",
    "Quantity",
    "UnitPrice",
    "CustomerID"
]].head(20)
# Out:
#      InvoiceNo StockCode Description  Quantity  UnitPrice  CustomerID
# 622     536414     22139         NaN        56        0.0         NaN
# 1970    536545     21134         NaN         1        0.0         NaN
# 1971    536546     22145         NaN         1        0.0         NaN
# 1972    536547     37509         NaN         1        0.0         NaN
# 1987    536549    85226A         NaN         1        0.0         NaN
# 1988    536550     85044         NaN         1        0.0         NaN
# 2024    536552     20950         NaN         1        0.0         NaN
# 2025    536553     37461         NaN         3        0.0         NaN
# 2026    536554     84670         NaN        23        0.0         NaN
# 2406    536589     21777         NaN       -10        0.0         NaN
# 4347    536764    84952C         NaN       -38        0.0         NaN
# 4348    536765    84952C         NaN        19        0.0         NaN
# ...

# %%
df["CustomerID"].isna().mean() * 100
# Out:
# np.float64(24.926694334288598)

# %%
df["CustomerID"].nunique()
# Out:
# 4372

# %%
df["transaction_type"].value_counts()
# Out:
# transaction_type
# SALE      527390
# RETURN      9251
# Name: count, dtype: int64

# %%
import sys
sys.path.append("..")

from etl.test_read import extract_data
from etl.transform import transform_data

df = extract_data()
df = transform_data(df)

df["transaction_type"].value_counts()
# Out:
# Successfully extracted 541,909 rows.
# transaction_type
# SALE      527390
# RETURN      9251
# Name: count, dtype: int64

# %%
df[df["unitprice"] <= 0][
    [
        "invoiceno",
        "stockcode",
        "description",
        "quantity",
        "unitprice",
        "customerid",
        "transaction_type"
    ]
].head(20)
# Out:
#      invoiceno stockcode description  quantity  unitprice  customerid  \
# 622     536414     22139         NaN        56        0.0        <NA>
# 1970    536545     21134         NaN         1        0.0        <NA>
# 1971    536546     22145         NaN         1        0.0        <NA>
# 1972    536547     37509         NaN         1        0.0        <NA>
# 1987    536549    85226A         NaN         1        0.0        <NA>
# 1988    536550     85044         NaN         1        0.0        <NA>
# 2024    536552     20950         NaN         1        0.0        <NA>
# 2025    536553     37461         NaN         3        0.0        <NA>
# 2026    536554     84670         NaN        23        0.0        <NA>
# 2406    536589     21777         NaN       -10        0.0        <NA>
# 4347    536764    84952C         NaN       -38        0.0        <NA>
# 4348    536765    84952C         NaN        19        0.0        <NA>
# ...

# %%
df[df["unitprice"] <= 0]["description"].value_counts(dropna=False).head(20)
# Out:
# description
# NaN                                1454
# check                               159
# ?                                    47
# damages                              45
# damaged                              43
# found                                25
# sold as set on dotcom                20
# adjustment                           16
# Damaged                              14
# FRENCH BLUE METAL DOOR SIGN 1         9
# thrown away                           9
# Unsaleable, destroyed.                9
# amazon                                8
# FRENCH BLUE METAL DOOR SIGN 8         8
# Found                                 8
# FRENCH BLUE METAL DOOR SIGN 4         7
# FRENCH BLUE METAL DOOR SIGN No        7
# OWL DOORSTOP                          7
# FRENCH BLUE METAL DOOR SIGN 3         7
# RECIPE BOX PANTRY YELLOW DESIGN       7
# Name: count, dtype: int64

# %%
df[(df["unitprice"] <= 0) & (df["customerid"].notna())].shape[0]
# Out:
# 40

# %%
df["description"].isna().sum()
# Out:
# np.int64(1454)

# %%
df = extract_data()
df = transform_data(df)
# Out:
# Successfully extracted 541,909 rows.

# %%
import importlib
import etl.transform

importlib.reload(etl.transform)

from etl.transform import transform_data

df = extract_data()
df = transform_data(df)

df["is_valid_sale"].value_counts()
# Out:
# Successfully extracted 541,909 rows.
# is_valid_sale
# True     392692
# False    143949
# Name: count, dtype: int64

# %%
sales_df = df[df["is_valid_sale"]].copy()

# %%
sales_df.shape
# Out:
# (392692, 11)

# %%
sales_df.head()
# Out:
#   invoiceno stockcode                          description  quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           invoicedate  unitprice  customerid         country  revenue  \
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom    20.34
#
#   transaction_type  is_valid_sale
# 0             SALE           True
# 1             SALE           True
# ...

# %%
from pathlib import Path

output_path = Path("../data/processed/sales.csv")

output_path.parent.mkdir(parents=True, exist_ok=True)

sales_df.to_csv(output_path, index=False)

print(f"Saved {len(sales_df):,} rows to {output_path}")
# Out:
# Saved 392,692 rows to ..\data\processed\sales.csv

# %%
processed_df = pd.read_csv("../data/processed/sales.csv")

print("Shape:", processed_df.shape)
print("\nMissing values:")
print(processed_df.isna().sum())
# Out:
# Shape: (392692, 11)
#
# Missing values:
# invoiceno           0
# stockcode           0
# description         0
# quantity            0
# invoicedate         0
# unitprice           0
# customerid          0
# country             0
# revenue             0
# transaction_type    0
# is_valid_sale       0
# dtype: int64
